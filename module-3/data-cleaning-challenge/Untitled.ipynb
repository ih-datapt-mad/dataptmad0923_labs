# %%
# !pip install scikit-learn
# Out:
# ...
#   Obtaining dependency information for scikit-learn from https://files.pythonhosted.org/packages/82/2c/4f9461018635112539d5ac86b4579a783dcb3f4fc9b49728e5b68a82beb8/scikit_learn-1.4.0-1-cp310-cp310-macosx_10_9_x86_64.whl.metadata
# ...
#   Obtaining dependency information for joblib>=1.2.0 from https://files.pythonhosted.org/packages/10/40/d551139c85db202f1f384ba8bcf96aca2f329440a844f924c8a0040b6d02/joblib-1.3.2-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for threadpoolctl>=2.0.0 from https://files.pythonhosted.org/packages/81/12/fd4dea011af9d69e1cad05c75f3f7202cdcbeac9b712eea58ca779a72865/threadpoolctl-3.2.0-py3-none-any.whl.metadata
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 25.0 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.2/302.2 kB 8.9 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import numpy as np

from sklearn.impute import SimpleImputer

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler

from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv('./data/iris-data.csv')

# %%
data
# Out:
#      sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0                5.1             3.5              1.4             0.2
# 1                4.9             3.0              1.4             0.2
# 2                4.7             3.2              1.3             0.2
# 3                4.6             3.1              1.5             0.2
# 4                5.0             3.6              1.4             0.2
# ..               ...             ...              ...             ...
# 145              6.7             3.0              5.2             2.3
# 146              6.3             2.5              5.0             2.3
# 147              6.5             3.0              5.2             2.0
# 148              6.2             3.4              5.4             2.3
# 149              5.9             3.0              5.1             1.8
#
#               class
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   sepal_length_cm  150 non-null    float64
#  1   sepal_width_cm   150 non-null    float64
#  2   petal_length_cm  150 non-null    float64
#  3   petal_width_cm   145 non-null    float64
#  4   class            150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
#hay 5 non-null en petal_width_cm y class es object en vez de float64(habra que hacer un one-hot-enconding)

# %%
data_null = data.dropna()

# %%
data_null.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 145 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   sepal_length_cm  145 non-null    float64
#  1   sepal_width_cm   145 non-null    float64
#  2   petal_length_cm  145 non-null    float64
#  3   petal_width_cm   145 non-null    float64
#  4   class            145 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.8+ KB

# %%
data_object = data['class'].value_counts()

# %%
data_object
# Out:
# class
# Iris-virginica     50
# Iris-setosa        49
# Iris-versicolor    45
# versicolor          5
# Iris-setossa        1
# Name: count, dtype: int64

# %%
data['class'] = data['class'].replace(['versicolor', 'Iris-setossa'], ['Iris-versicolor', 'Iris-setosa'])

# %%
data_object2 = data['class'].value_counts()
data_object2
# Out:
# class
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
data_enconding = pd.get_dummies(data, columns=['class'], dtype=float)

# %%
data_enconding
# Out:
#      sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0                5.1             3.5              1.4             0.2
# 1                4.9             3.0              1.4             0.2
# 2                4.7             3.2              1.3             0.2
# 3                4.6             3.1              1.5             0.2
# 4                5.0             3.6              1.4             0.2
# ..               ...             ...              ...             ...
# 145              6.7             3.0              5.2             2.3
# 146              6.3             2.5              5.0             2.3
# 147              6.5             3.0              5.2             2.0
# 148              6.2             3.4              5.4             2.3
# 149              5.9             3.0              5.1             1.8
#
#      class_Iris-setosa  class_Iris-versicolor  class_Iris-virginica
# ...

# %%
data_enconding.drop()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   sepal_length_cm        150 non-null    float64
#  1   sepal_width_cm         150 non-null    float64
#  2   petal_length_cm        150 non-null    float64
#  3   petal_width_cm         145 non-null    float64
#  4   class_Iris-setosa      150 non-null    float64
#  5   class_Iris-versicolor  150 non-null    float64
#  6   class_Iris-virginica   150 non-null    float64
# dtypes: float64(7)
# memory usage: 8.3 KB

# %%
data_clean = data_enconding.dropna()

# %%
data_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 145 entries, 0 to 149
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   sepal_length_cm        145 non-null    float64
#  1   sepal_width_cm         145 non-null    float64
#  2   petal_length_cm        145 non-null    float64
#  3   petal_width_cm         145 non-null    float64
#  4   class_Iris-setosa      145 non-null    float64
#  5   class_Iris-versicolor  145 non-null    float64
#  6   class_Iris-virginica   145 non-null    float64
# dtypes: float64(7)
# memory usage: 9.1 KB

# %%
data_clean
# Out:
#      sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0                5.1             3.5              1.4             0.2
# 1                4.9             3.0              1.4             0.2
# 2                4.7             3.2              1.3             0.2
# 3                4.6             3.1              1.5             0.2
# 4                5.0             3.6              1.4             0.2
# ..               ...             ...              ...             ...
# 145              6.7             3.0              5.2             2.3
# 146              6.3             2.5              5.0             2.3
# 147              6.5             3.0              5.2             2.0
# 148              6.2             3.4              5.4             2.3
# 149              5.9             3.0              5.1             1.8
#
#      class_Iris-setosa  class_Iris-versicolor  class_Iris-virginica
# ...

# %%
data_clean.to_csv('./data/iris_data_clean.csv', index=False)
