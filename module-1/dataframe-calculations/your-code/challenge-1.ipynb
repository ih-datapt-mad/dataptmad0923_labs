# %% [markdown]
# # Challenge 1
#
# In this challenge you will be working on **Pokemon**. You will answer a series of questions in order to practice dataframe calculation, aggregation, and transformation.
#
# ![Pokemon](../images/pokemon.jpg)
#
# Follow the instructions below and enter your code.
#
# #### Import all required libraries.

# %%
# import libraries

# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# #### Import data set.
#
# Import data set `Pokemon` from Ironhack's database. Read the data into a dataframe called `pokemon`.
#
# *Data set attributed to [Alberto Barradas](https://www.kaggle.com/abcsds/pokemon/)*

# %%
# import data set from Ironhack's database

# %%
pokemon = pd.read_csv("./data/Pokemon.csv")

# %% [markdown]
# #### Print first 10 rows of `pokemon`.

# %%
# your code here

# %%
pokemon.head(11)
# Out:
#     #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0   1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1   2                    Ivysaur  Grass  Poison    405  60      62       63
# 2   3                   Venusaur  Grass  Poison    525  80      82       83
# 3   3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4   4                 Charmander   Fire     NaN    309  39      52       43
# 5   5                 Charmeleon   Fire     NaN    405  58      64       58
# 6   6                  Charizard   Fire  Flying    534  78      84       78
# 7   6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8   6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9   7                   Squirtle  Water     NaN    314  44      48       65
# 10  8                  Wartortle  Water     NaN    405  59      63       80
#
#     Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0        65       65     45           1      False
# 1        80       80     60           1      False
# 2       100      100     80           1      False
# 3       122      120     80           1      False
# 4        60       50     65           1      False
# 5        80       65     80           1      False
# 6       109       85    100           1      False
# 7       130       85    100           1      False
# 8       159      115    100           1      False
# 9        50       64     43           1      False
# 10       65       80     58           1      False

# %% [markdown]
# When you look at a data set, you often wonder what each column means. Some open-source data sets provide descriptions of the data set. In many cases, data descriptions are extremely useful for data analysts to perform work efficiently and successfully.
#
# For the `Pokemon.csv` data set, fortunately, the owner provided descriptions which you can see [here](https://www.kaggle.com/abcsds/pokemon/home). For your convenience, we are including the descriptions below. Read the descriptions and understand what each column means. This knowledge is helpful in your work with the data.
#
# | Column | Description |
# | --- | --- |
# | # | ID for each pokemon |
# | Name | Name of each pokemon |
# | Type 1 | Each pokemon has a type, this determines weakness/resistance to attacks |
# | Type 2 | Some pokemon are dual type and have 2 |
# | Total | A general guide to how strong a pokemon is |
# | HP | Hit points, or health, defines how much damage a pokemon can withstand before fainting |
# | Attack | The base modifier for normal attacks (eg. Scratch, Punch) |
# | Defense | The base damage resistance against normal attacks |
# | SP Atk | Special attack, the base modifier for special attacks (e.g. fire blast, bubble beam) |
# | SP Def | The base damage resistance against special attacks |
# | Speed | Determines which pokemon attacks first each round |
# | Generation | Number of generation |
# | Legendary | True if Legendary Pokemon False if not |

# %% [markdown]
# #### Obtain the distinct values across `Type 1` and `Type 2`.
#
# Exctract all the values in `Type 1` and `Type 2`. Then create an array containing the distinct values across both fields.

# %%
# your code here

# %%
type1_values = pokemon['Type 1'].unique()
type1_values
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %%
type2_values = pokemon['Type 2'].unique()
type2_values
# Out:
# array(['Poison', nan, 'Flying', 'Dragon', 'Ground', 'Fairy', 'Grass',
#        'Fighting', 'Psychic', 'Steel', 'Ice', 'Rock', 'Dark', 'Water',
#        'Electric', 'Fire', 'Ghost', 'Bug', 'Normal'], dtype=object)

# %%
all_types = pd.Series(list(type1_values) + list(type2_values))
all_types
# Out:
# 0        Grass
# 1         Fire
# 2        Water
# 3          Bug
# 4       Normal
# 5       Poison
# 6     Electric
# 7       Ground
# 8        Fairy
# 9     Fighting
# 10     Psychic
# 11        Rock
# 12       Ghost
# 13         Ice
# 14      Dragon
# 15        Dark
# 16       Steel
# 17      Flying
# 18      Poison
# 19         NaN
# 20      Flying
# 21      Dragon
# 22      Ground
# 23       Fairy
# 24       Grass
# 25    Fighting
# 26     Psychic
# 27       Steel
# 28         Ice
# 29        Rock
# 30        Dark
# 31       Water
# 32    Electric
# 33        Fire
# 34       Ghost
# 35         Bug
# 36      Normal
# dtype: object

# %%
distinct_values = all_types.unique()
distinct_values
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying', nan], dtype=object)

# %%
print(type(distinct_values))
# Out:
# <class 'numpy.ndarray'>

# %% [markdown]
# #### Cleanup `Name` that contain "Mega".
#
# If you have checked out the pokemon names carefully enough, you should have found there are junk texts in the pokemon names which contain "Mega". We want to clean up the pokemon names. For instance, "VenusaurMega Venusaur" should be "Mega Venusaur", and "CharizardMega Charizard X" should be "Mega Charizard X".

# %%
# your code here


# test transformed data
pokemon.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False
# 5       80       65     80           1      False
# 6      109       85    100           1      False
# 7      130       85    100           1      False
# 8      159      115    100           1      False
# 9       50       64     43           1      False

# %%
import re

# %%
pokemon['Name'] = pokemon['Name'].replace('.*Mega','Mega', regex = True)

# %%
pokemon.head(10)
# Out:
#    #              Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0  1         Bulbasaur  Grass  Poison    318  45      49       49       65
# 1  2           Ivysaur  Grass  Poison    405  60      62       63       80
# 2  3          Venusaur  Grass  Poison    525  80      82       83      100
# 3  3     Mega Venusaur  Grass  Poison    625  80     100      123      122
# 4  4        Charmander   Fire     NaN    309  39      52       43       60
# 5  5        Charmeleon   Fire     NaN    405  58      64       58       80
# 6  6         Charizard   Fire  Flying    534  78      84       78      109
# 7  6  Mega Charizard X   Fire  Dragon    634  78     130      111      130
# 8  6  Mega Charizard Y   Fire  Flying    634  78     104       78      159
# 9  7          Squirtle  Water     NaN    314  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False
# 5       65     80           1      False
# 6       85    100           1      False
# 7       85    100           1      False
# 8      115    100           1      False
# 9       64     43           1      False

# %% [markdown]
# #### Create a new column called `A/D Ratio` whose value equals to `Attack` devided by `Defense`.
#
# For instance, if a pokemon has the Attack score 49 and Defense score 49, the corresponding `A/D Ratio` is 49/49=1.

# %%
# your code here

# %%
pokemon['A/D Ratio'] = pokemon.apply(lambda row: (row["Attack"]/row["Defense"]),axis=1)
pokemon.head()
# Out:
#    #           Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0  1      Bulbasaur  Grass  Poison    318  45      49       49       65
# 1  2        Ivysaur  Grass  Poison    405  60      62       63       80
# 2  3       Venusaur  Grass  Poison    525  80      82       83      100
# 3  3  Mega Venusaur  Grass  Poison    625  80     100      123      122
# 4  4     Charmander   Fire     NaN    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  A/D Ratio
# 0       65     45           1      False   1.000000
# 1       80     60           1      False   0.984127
# 2      100     80           1      False   0.987952
# 3      120     80           1      False   0.813008
# 4       50     65           1      False   1.209302

# %% [markdown]
# #### Identify the pokemon with the highest `A/D Ratio`.

# %%
# your code here

# %%
highest_ADRatio_pokemon = pokemon[pokemon['A/D Ratio'] == pokemon['A/D Ratio'].max()]

# %%
highest_ADRatio_pokemon
# Out:
#        #                Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 429  386  DeoxysAttack Forme  Psychic    NaN    600  50     180       20
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  A/D Ratio
# 429      180       20    150           3       True        9.0

# %% [markdown]
# #### Identify the pokemon with the lowest A/D Ratio.

# %%
# your code here

# %%
lowest_ADRatio_pokemon = pokemon[pokemon['A/D Ratio'] == pokemon['A/D Ratio'].min()]

# %%
lowest_ADRatio_pokemon
# Out:
#        #     Name Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 230  213  Shuckle    Bug   Rock    505  20      10      230       10      230
#
#      Speed  Generation  Legendary  A/D Ratio
# 230      5           2      False   0.043478

# %% [markdown]
# #### Create a new column called `Combo Type` whose value combines `Type 1` and `Type 2`.
#
# Rules:
#
# * If both `Type 1` and `Type 2` have valid values, the `Combo Type` value should contain both values in the form of `<Type 1> <Type 2>`. For example, if `Type 1` value is `Grass` and `Type 2` value is `Poison`, `Combo Type` will be `Grass-Poison`.
#
# * If `Type 1` has valid value but `Type 2` is not, `Combo Type` will be the same as `Type 1`. For example, if `Type 1` is `Fire` whereas `Type 2` is `NaN`, `Combo Type` will be `Fire`.

# %%
# your code here

# %%
def rules(type1_value,type2_value):
    if not type1_value:
        return type2_value
    elif not type2_value:
        return type1_value
    else:
        return type1_value + '-' + type2_value

# %%
rules('Grass','Poison')
# Out:
# 'Grass-Poison'

# %%
rules('Fire', None)
# Out:
# 'Fire'

# %%
rules(None ,'Fire')
# Out:
# 'Fire'

# %%
pokemon['Type 1'] = pokemon['Type 1'].astype('string')

# %%
pokemon['Type 2'] = pokemon['Type 2'].astype('string')

# %%
pokemon['Combo Type'] = pokemon.apply(lambda row: rules(row["Type 1"],row["Type 2"]),axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [35], in <cell line: 1>()
# ----> 1 pokemon['Combo Type'] = pokemon.apply(lambda row: rules(row["Type 1"],row["Type 2"]),axis=1)
#
# File ~/miniconda3/envs/jupyter_env/lib/python3.10/site-packages/pandas/core/frame.py:9423, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9412 from pandas.core.apply import frame_apply
#    9414 op = frame_apply(
#    9415     self,
#    9416     func=func,
#    (...)
#    9421     kwargs=kwargs,
#    9422 )
# -> 9423 return op.apply().__finalize__(self, method="apply")
#
# File ~/miniconda3/envs/jupyter_env/lib/python3.10/site-packages/pandas/core/apply.py:678, in FrameApply.apply(self)
#     675 elif self.raw:
#     676     return self.apply_raw()
# --> 678 return self.apply_standard()
#
# File ~/miniconda3/envs/jupyter_env/lib/python3.10/site-packages/pandas/core/apply.py:798, in FrameApply.apply_standard(self)
#     797 def apply_standard(self):
# --> 798     results, res_index = self.apply_series_generator()
#     800     # wrap results
#     801     return self.wrap_results(results, res_index)
#
# File ~/miniconda3/envs/jupyter_env/lib/python3.10/site-packages/pandas/core/apply.py:814, in FrameApply.apply_series_generator(self)
#     811 with option_context("mode.chained_assignment", None):
#     812     for i, v in enumerate(series_gen):
#     813         # ignore SettingWithCopy here in case the user mutates
# --> 814         results[i] = self.f(v)
#     815         if isinstance(results[i], ABCSeries):
#     816             # If we have a view on v, we need to make a copy because
#     817             #  series_generator will swap out the underlying data
#     818             results[i] = results[i].copy(deep=False)
#
# Input In [35], in <lambda>(row)
# ----> 1 pokemon['Combo Type'] = pokemon.apply(lambda row: rules(row["Type 1"],row["Type 2"]),axis=1)
#
# Input In [30], in rules(type1_value, type2_value)
#       2 if not type1_value:
#       3     return type2_value
# ----> 4 elif not type2_value:
#       5     return type1_value
#       6 else:
#
# File ~/miniconda3/envs/jupyter_env/lib/python3.10/site-packages/pandas/_libs/missing.pyx:388, in pandas._libs.missing.NAType.__bool__()
#
# TypeError: boolean value of NA is ambiguous

# %%
#Otra forma

pokemon['Combo Type'] = pokemon['Type 1']
pokemon.loc[pokemon['Type 2'].notnull(),['Combo Type']] = pokemon['Type 1'] + '-' + pokemon['Type 2']

#El .loc te sirve para filtrar por una condición, entonces estableces la condición que es que el Type 2 no sea nulo y entonces estás filtrando la tabla para las filas que cumplan la condición
#Antes de la coma la condición y después de la coma las columnas que te quieres quedar.

# %%
pokemon.head(10)
# Out:
#    #              Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0  1         Bulbasaur  Grass  Poison    318  45      49       49       65
# 1  2           Ivysaur  Grass  Poison    405  60      62       63       80
# 2  3          Venusaur  Grass  Poison    525  80      82       83      100
# 3  3     Mega Venusaur  Grass  Poison    625  80     100      123      122
# 4  4        Charmander   Fire     NaN    309  39      52       43       60
# 5  5        Charmeleon   Fire     NaN    405  58      64       58       80
# 6  6         Charizard   Fire  Flying    534  78      84       78      109
# 7  6  Mega Charizard X   Fire  Dragon    634  78     130      111      130
# 8  6  Mega Charizard Y   Fire  Flying    634  78     104       78      159
# 9  7          Squirtle  Water     NaN    314  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary  A/D Ratio    Combo Type
# 0       65     45           1      False   1.000000  Grass-Poison
# 1       80     60           1      False   0.984127  Grass-Poison
# 2      100     80           1      False   0.987952  Grass-Poison
# 3      120     80           1      False   0.813008  Grass-Poison
# 4       50     65           1      False   1.209302          Fire
# 5       65     80           1      False   1.103448          Fire
# 6       85    100           1      False   1.076923   Fire-Flying
# 7       85    100           1      False   1.171171   Fire-Dragon
# 8      115    100           1      False   1.333333   Fire-Flying
# 9       64     43           1      False   0.738462         Water

# %% [markdown]
# #### Identify the pokemon whose `A/D Ratio` are among the top 5.

# %%
# your code here

# %%
top_5_pokemon = pokemon.sort_values(by='A/D Ratio', ascending=False).head(5)

# %%
top_5_pokemon
# Out:
#        #                Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 429  386  DeoxysAttack Forme  Psychic     NaN    600  50     180       20
# 347  318            Carvanha    Water    Dark    305  45      90       20
# 19    15       Mega Beedrill      Bug  Poison    495  65     150       40
# 453  408            Cranidos     Rock     NaN    350  67     125       40
# 348  319            Sharpedo    Water    Dark    460  70     120       40
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  A/D Ratio  Combo Type
# 429      180       20    150           3       True      9.000     Psychic
# 347       65       20     65           3      False      4.500  Water-Dark
# 19        15       80    145           1      False      3.750  Bug-Poison
# 453       30       30     58           4      False      3.125        Rock
# 348       95       40     95           3      False      3.000  Water-Dark

# %% [markdown]
# #### For the 5 pokemon printed above, aggregate `Combo Type` and use a list to store the unique values.
#
# Your end product is a list containing the distinct `Combo Type` values of the 5 pokemon with the highest `A/D Ratio`.

# %%
# your code here

# %%
top_5_pokemon_combo_type = list(top_5_pokemon['Combo Type'].unique())
top_5_pokemon_combo_type
# Out:
# ['Psychic', 'Water-Dark', 'Bug-Poison', 'Rock']

# %% [markdown]
# #### For each of the `Combo Type` values obtained from the previous question, calculate the mean scores of all numeric fields across all pokemon.
#
# Your output should look like below:
#
# ![Aggregate](../images/aggregated-mean.png)

# %%
# your code here

# %%
#Tengo el data frame con los valores numéricos

# %%
pokemon.select_dtypes(include=np.number)
# Out:
#        #  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  \
# 0      1    318  45      49       49       65       65     45           1
# 1      2    405  60      62       63       80       80     60           1
# 2      3    525  80      82       83      100      100     80           1
# 3      3    625  80     100      123      122      120     80           1
# 4      4    309  39      52       43       60       50     65           1
# ..   ...    ...  ..     ...      ...      ...      ...    ...         ...
# 795  719    600  50     100      150      100      150     50           6
# 796  719    700  50     160      110      160      110    110           6
# 797  720    600  80     110       60      150      130     70           6
# 798  720    680  80     160       60      170      130     80           6
# 799  721    600  80     110      120      130       90     70           6
#
#      A/D Ratio
# 0     1.000000
# 1     0.984127
# 2     0.987952
# 3     0.813008
# 4     1.209302
# ..         ...
# 795   0.666667
# 796   1.454545
# 797   1.833333
# 798   2.666667
# 799   0.916667
#
# [800 rows x 10 columns]

# %%
#A este data frame le añado la columna Combo Type con un join

# %%
data_frame = pokemon.select_dtypes(include=np.number).join(pokemon['Combo Type'])

# %%
data_frame
# Out:
#        #  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  \
# 0      1    318  45      49       49       65       65     45           1
# 1      2    405  60      62       63       80       80     60           1
# 2      3    525  80      82       83      100      100     80           1
# 3      3    625  80     100      123      122      120     80           1
# 4      4    309  39      52       43       60       50     65           1
# ..   ...    ...  ..     ...      ...      ...      ...    ...         ...
# 795  719    600  50     100      150      100      150     50           6
# 796  719    700  50     160      110      160      110    110           6
# 797  720    600  80     110       60      150      130     70           6
# 798  720    680  80     160       60      170      130     80           6
# 799  721    600  80     110      120      130       90     70           6
#
#      A/D Ratio     Combo Type
# 0     1.000000   Grass-Poison
# 1     0.984127   Grass-Poison
# 2     0.987952   Grass-Poison
# 3     0.813008   Grass-Poison
# 4     1.209302           Fire
# ..         ...            ...
# 795   0.666667     Rock-Fairy
# 796   1.454545     Rock-Fairy
# 797   1.833333  Psychic-Ghost
# 798   2.666667   Psychic-Dark
# 799   0.916667     Fire-Water
#
# [800 rows x 11 columns]

# %%
#Ya tengo el data frame al que quiero hacer las operaciones: la media agrupada por el combo type

# %%
media_numeric_df = pokemon.select_dtypes(include=np.number).join(pokemon['Combo Type']).groupby('Combo Type').mean()

# %%
media_numeric_df
# Out:
#                         #       Total         HP      Attack     Defense  \
# Combo Type
# Bug            361.352941  289.705882  53.058824   50.352941   55.411765
# Bug-Electric   595.500000  395.500000  60.000000   62.000000   55.000000
# Bug-Fighting   214.000000  550.000000  80.000000  155.000000   95.000000
# Bug-Fire       636.500000  455.000000  70.000000   72.500000   60.000000
# Bug-Flying     286.285714  419.500000  63.000000   70.142857   61.571429
# ...                   ...         ...        ...         ...         ...
# Water-Ice      103.000000  511.666667  90.000000   83.333333  113.333333
# Water-Poison   118.666667  426.666667  61.666667   68.333333   58.333333
# Water-Psychic  111.800000  481.000000  87.000000   73.000000  104.000000
# Water-Rock     430.000000  428.750000  70.750000   82.750000  112.750000
# Water-Steel    395.000000  530.000000  84.000000   86.000000   88.000000
#
#                   Sp. Atk     Sp. Def      Speed  Generation  A/D Ratio
# Combo Type
# Bug             39.294118   43.647059  47.941176    3.470588   0.940179
# Bug-Electric    77.000000   55.000000  86.500000    5.000000   1.111667
# Bug-Fighting    40.000000  100.000000  80.000000    2.000000   1.637681
# Bug-Fire        92.500000   80.000000  80.000000    5.000000   1.234266
# Bug-Flying      72.857143   69.071429  82.857143    2.857143   1.146274
# ...                   ...         ...        ...         ...        ...
# Water-Ice       80.000000   78.333333  66.666667    1.000000   0.821759
# Water-Poison    61.666667   91.666667  85.000000    1.333333   1.162149
# Water-Psychic   94.000000   79.000000  44.000000    1.200000   0.783668
# Water-Rock      61.500000   65.000000  36.000000    3.750000   0.727170
# Water-Steel    111.000000  101.000000  60.000000    4.000000   0.977273
#
# [154 rows x 10 columns]

# %%
dataframe = pokemon.select_dtypes(include=np.number).join(pokemon['Combo Type'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [102], in <cell line: 1>()
# ----> 1 pokemon.select_dtypes(include=np.number).join(pokemon['Combo Type']).loc[pokemon['Combo Type'] in top_5_pokemon_combo_type,].groupby('Combo Type').mean()
#
# File ~/miniconda3/envs/jupyter_env/lib/python3.10/site-packages/pandas/core/generic.py:1466, in NDFrame.__nonzero__(self)
#    1464 @final
#    1465 def __nonzero__(self) -> NoReturn:
# -> 1466     raise ValueError(
#    1467         f"The truth value of a {type(self).__name__} is ambiguous. "
#    1468         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1469     )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
data_frame.loc[data_frame['Combo Type'] in top_5_pokemon_combo_type,].groupby('Combo Type').mean()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [106], in <cell line: 1>()
# ----> 1 data_frame.loc[data_frame['Combo Type'] in top_5_pokemon_combo_type,].groupby('Combo Type').mean()
#
# File ~/miniconda3/envs/jupyter_env/lib/python3.10/site-packages/pandas/core/generic.py:1466, in NDFrame.__nonzero__(self)
#    1464 @final
#    1465 def __nonzero__(self) -> NoReturn:
# -> 1466     raise ValueError(
#    1467         f"The truth value of a {type(self).__name__} is ambiguous. "
#    1468         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1469     )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
#Solución correcta

# %%
media_numeric_df.loc[top_5_pokemon_combo_type,]
# Out:
#                      #       Total         HP      Attack     Defense  \
# Combo Type
# Psychic     381.973684  464.552632  72.552632   64.947368   67.236842
# Water-Dark  347.666667  493.833333  69.166667  120.000000   65.166667
# Bug-Poison  199.166667  347.916667  53.750000   68.333333   58.083333
# Rock        410.111111  409.444444  67.111111  103.333333  107.222222
#
#               Sp. Atk    Sp. Def      Speed  Generation  A/D Ratio
# Combo Type
# Psychic     98.552632  82.394737  78.868421    3.342105   1.164196
# Water-Dark  88.833333  63.500000  87.166667    3.166667   2.291949
# Bug-Poison  42.500000  59.333333  65.916667    2.333333   1.315989
# Rock        40.555556  58.333333  32.888889    3.888889   1.260091
